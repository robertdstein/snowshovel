# %%
from snowshovel.io import read_single_alert, parse_alerts
import pandas as pd
from tqdm import tqdm
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.coordinates import Angle

# Set this to the directory containing the unzipped avro alerts
data_dir = Path("/Users/oakpa/Desktop/Al_Summer/Avro_Files")

# Set the number of alerts to read
n_to_read = 71708

# %matplotlib inline

# %%
import pandas as pd
names = [
    "ra",
    "dec",
    "name",
    "type",
    "r_mag",
    "b_mag",
    "comment",
    "r",
    "b",
    "redshift",
    "cite",
    "zcite",
    "rxpct",
    "qpct",
    "xname",
    "rname",
    "lobe1",
    "lobe2",
]

colspecs = [
    (0, 10),
    (12, 22),
    (25, 49),
    (51, 54),
    (56, 60),
    (62, 66),
    (68, 70),
    (72, 73),
    (74, 75),
    (76, 81),
    (83, 88),
    (90, 95),
    (97, 99),
    (101, 103),
    (105, 126),
    (128, 149),
    (151, 172),
    (174, 195),
]

mq_data = pd.read_fwf("C:\\Users\\oakpa\\Desktop\\Al_Summer\\Milliquas.txt", names=names, colspecs=colspecs)
     # with this command you can see your file

# %%
alert_path = data_dir.parent.joinpath("winter_avro")
print(alert_path)
alerts_df = parse_alerts(data_dir=alert_path, n_to_read=1000)
# Out:
# \Users\oakpa\Desktop\Al_Summer\winter_avro
#  28%|██████████████████████                                                         | 279/1000 [00:16<00:41, 17.29it/s]

# %%
alerts_df
# Out:
#                jd  diffmaglim  fid programpi  programid         candid  \
# 0    2.460137e+06   17.102144    2     Stein          1  2460136710000
# 1    2.460137e+06   17.102144    2     Stein          1  2460136710001
# 2    2.460137e+06   17.102144    2     Stein          1  2460136710002
# 3    2.460137e+06   17.102144    2     Stein          1  2460136710003
# 4    2.460137e+06   17.102144    2     Stein          1  2460136710004
# ..            ...         ...  ...       ...        ...            ...
# 274  2.460137e+06   17.119339    2    WINTER          1  2460136940096
# 275  2.460137e+06   17.119339    2    WINTER          1  2460136940097
# 276  2.460137e+06   17.119339    2    WINTER          1  2460136940098
# 277  2.460137e+06   17.119339    2    WINTER          1  2460136940099
# 278  2.460137e+06   17.119339    2    WINTER          1  2460136940100
#
#      isdiffpos  field  ndethist         xpos  ...  clrcounc  zpclrcov  zpmed  \
# 0          1.0   3944         1  1003.802002  ...      None      None   None
# 1          1.0   3944         1   762.754822  ...      None      None   None
# 2          1.0   3944         1   385.960724  ...      None      None   None
# 3          1.0   3944         1   418.946777  ...      None      None   None
# 4          1.0   3944         1   808.882385  ...      None      None   None
# ..         ...    ...       ...          ...  ...       ...       ...    ...
# 274        1.0   6124         1   526.009705  ...      None      None   None
# 275        1.0   6124         1   504.338074  ...      None      None   None
# 276        1.0   6124         1   503.845795  ...      None      None   None
# 277        1.0   6124         1   510.754639  ...      None      None   None
# 278        1.0   6124         1   525.490906  ...      None      None   None
#
#      clrmed  clrrms  neargaia  neargaiabright  maggaia maggaiabright exptime
# 0      None    None      None            None     None          None   720.0
# 1      None    None      None            None     None          None   720.0
# 2      None    None      None            None     None          None   720.0
# 3      None    None      None            None     None          None   720.0
# 4      None    None      None            None     None          None   720.0
# ..      ...     ...       ...             ...      ...           ...     ...
# 274    None    None      None            None     None          None   600.0
# 275    None    None      None            None     None          None   600.0
# 276    None    None      None            None     None          None   600.0
# 277    None    None      None            None     None          None   600.0
# 278    None    None      None            None     None          None   600.0
#
# [279 rows x 103 columns]

# %%
##Data has been fully loaded into separate csv files

# def make_bins(nb_bins):
#     dex = np.linspace(-90., 90., nb_bins+1)
#     return dex

# nb_bin = 30

# dex = make_bins(nb_bin)

# dec_index_mq = range(nb_bin)

# mq_data['mq_cut'] = pd.cut(x=mq_data['dec'],bins=dex, labels=dec_index_mq)

# mq_output_dir = data_dir.parent.joinpath(f'Sorted_Milliquas_{nb_bin}')
# mq_output_dir.mkdir(exist_ok=True)

# mq_savepath=mq_output_dir.joinpath('milliquas_data.csv')
# mq_data.to_csv(mq_savepath)

# for i in dec_index_mq:
#     mask = mq_data['mq_cut'] == i
#     mq_cut_df = mq_data[mask]
#     mq_altpath = mq_output_dir.joinpath(f'milliquas_range_{i}.csv')
#     mq_cut_df.to_csv(mq_altpath, index = True)

# %%
# alert = read_single_alert(alert_path)
# print("An avro alert is just a python dictionary, as you can see below:")
# alert

# %%
useful_columns = [
    "isdiffpos", # Is the detection postive (more flux in science image than reference), or negative (less flux)?
    "ra", # What is the sky position in Right Ascension?
    "dec", # What is the sky position in Declination?
    "magpsf", # What is the magnitude (brightness) of the detection?
    "sigmapsf", # What is the uncertainty on the magnitude?
    "distnr", # How close is the detection to a known source in the reference image?
    "ndethist", # How many times has this object been detected?
    "candid",
    "objectId"
]
slim_alerts_df = alerts_df[useful_columns]
slim_alerts_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       1 useful_columns = [
#       2     "isdiffpos", # Is the detection postive (more flux in science image than reference), or negative (less flux)?
#       3     "ra", # What is the sky position in Right Ascension?
#    (...)
#      10     "objectId"
#      11 ]
# ---> 12 slim_alerts_df = alerts_df[useful_columns]
#      13 slim_alerts_df
#
# NameError: name 'alerts_df' is not defined

# %%
# Bad subtractions are often not repeated
# Let's restrict ourselves to sources which are detected at least twice
mask = slim_alerts_df["ndethist"] > 1
slim_alerts_df = slim_alerts_df[mask].reset_index()
print(f"There are {len(slim_alerts_df)} alerts passing our cut")
slim_alerts_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Bad subtractions are often not repeated
#       2 # Let's restrict ourselves to sources which are detected at least twice
# ----> 3 mask = slim_alerts_df["ndethist"] > 1
#       4 slim_alerts_df = slim_alerts_df[mask].reset_index()
#       5 print(f"There are {len(slim_alerts_df)} alerts passing our cut")
#
# NameError: name 'slim_alerts_df' is not defined

# %%
def make_bins(n_bins):
    decs = np.linspace(-90., 90., n_bins+1)
    return decs

n_bin = 30

decs = make_bins(n_bin)

dec_index = range(n_bin)

slim_alerts_df['my_cut'] = pd.cut(x=slim_alerts_df['dec'],bins=decs, labels=dec_index)

avro_output_dir = data_dir.parent.joinpath(f'Sorted_Avro_{n_bin}')
# print(avro_output_dir)
avro_output_dir.mkdir(exist_ok=True)

avro_savepath=avro_output_dir.joinpath('slim_alerts_data.csv')
# print(avro_savepath)
slim_alerts_df.to_csv(avro_savepath, index = False)

for i in dec_index:
    mask = slim_alerts_df['my_cut'] == i
    cut_df = slim_alerts_df[mask]
    avro_altpath = avro_output_dir.joinpath(f'slim_alerts_range_{i}.csv')
    cut_df.to_csv(avro_altpath, index = False)

# %%
# list_true = []

# #list of images (candidate ID (names of avro alert))

# for index in range(1):
#     c1 = SkyCoord(ra=slim_alerts_range_1.csv['ra'][index]*u.degree, dec=slim_alerts_range_1['dec'][index]*u.degree, frame='icrs')
#     for index in range(len(mq6)):
#         c2 = SkyCoord(ra=milliquas_range_1['ra'][index]*u.degree, dec=milliquas_range_1['dec'][index]*u.degree, frame='icrs')
#         a = c1.separation(c2)
#         if a<=1.5*u.arcsec:
#             print(a)
#             list_true.append(c1)
# print(len(mq_data))
# print(list_true)
# print(outcomes)

# %%
slim_sets = {}
mq_sets = {}
set_num = 0
total_set_num = 29
while set_num <= total_set_num:
    slim_filename = f'slim_alerts_range_{set_num}.csv'
    slim_path = Path(f"/Users/oakpa/Desktop/Al_Summer/Sorted_Avro_30/{slim_filename}")
    slim_sets[f'slim_set{set_num}'] = pd.read_csv(slim_path)
    
    mq_filename = f'milliquas_range_{set_num}.csv'
    mq_path = Path(f"/Users/oakpa/Desktop/Al_Summer/Sorted_Milliquas_30/{mq_filename}")
    mq_sets[f'mq_set{set_num}'] = pd.read_csv(mq_path)
    set_num += 1
    print("hi")
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
# have to do this again after reading the bin/set files, probably due the "Coordinate" column not being saved as the 
# proper data type; it probably made it into a string/object instead of what it is supposed to be 

# loop through each slim_set, create a coordinate and put value into new "Coordinate" column (for comparisons later)
for set_name, slim_set in tqdm(slim_sets.items(), desc='Processing slim_sets'):
    # update the 'Coordinate' column for the current slim_set
    slim_set["Coordinate"] = SkyCoord(slim_set["ra"], slim_set["dec"], frame='icrs', unit='deg')

# do the same for var_star_set
for set_name, mq_set in tqdm(mq_sets.items(), desc='Processing mq_sets'):
    # Update the 'Coordinate' column for the current var_star_set
    mq_set["Coordinate"] = SkyCoord(mq_set["ra"], mq_set["dec"], frame='icrs', unit='deg')

# %%
# create a list to store the results
results = []

# the set that is being compared
set_num = 18

# get the total number of iterations for tqdm to predict time
total_iterations = len(slim_sets[f'slim_set{set_num}'])

# define the threshold value for dec in arc seconds; masking parts of the set for optimization 
# if too low the code breaks due to comparing something to nothing in the filtered set; might have to change for each pair
# probably a good thing. if code doesn't break that means accuracy isn't lost. if it breaks, accuracy would be lost
cut_threshold = 50
# options are "degree", "arcmin", and "arcsec"
unit_type = "arcsec"

# current thresholds: set 14 (has to be in the degrees), set 13 (10 arcseconds), set 12 (10 arcseconds), set 11 (10 arcseconds)

# use tqdm to track progress
# iterating through each data point in the 'coordinate' column for slim_set{set_num}
for slim_index, slim_row in tqdm(slim_sets[f'slim_set{set_num}'].iterrows(), total=total_iterations, desc='Processing coordinates'):
    slim_coord = slim_row['Coordinate']
    
    # creating a list to store the distances for the current slim_set9 coordinate
    # will be used to determine the shortest distance
    distances = []
    # creating a list to store the corresponding indexes in variable_star
    # so we know which data point the shortest distance refers to
    mq_indexes = [] # note that this is no longer being utilized, can be added to the new data frame if desired though
    
    # filter var_star_set{set_num} based on declination; ± the threshold (inclusive)
    mq_set_filtered = mq_sets[f'mq_set{set_num}'][
        (mq_sets[f'mq_set{set_num}']['dec'] >= slim_coord.dec - Angle(cut_threshold, unit=unit_type)) &
        (mq_sets[f'mq_set{set_num}']['dec'] <= slim_coord.dec + Angle(cut_threshold, unit=unit_type))
    ]
    
    # iterate through each data point in the 'coordinate' column in the filtered var_star_set
    for mq_index, mq_row in mq_set_filtered.iterrows():
        mq_coord = mq_row['Coordinate']
        
        # calculate the distance between the two coordinates, record information in the two lists
        dist = slim_coord.separation(mq_coord)
        distances.append(dist)
        mq_indexes.append(mq_index)
    
    # find the smallest distance in the list and its corresponding index in variable_star
    if len(distances)>0:
        smallest_dist = min(distances)
        mq_index = mq_indexes[distances.index(smallest_dist)]
    
    # get the coordinates corresponding to the found indexes
    slim_candid = slim_sets[f'slim_set{set_num}'].loc[slim_index, "candid"]
#     slim_objectId = slim_sets[f'slim_set{set_num}'].loc[slim_index, "objectId"]
    mq_name = mq_sets[f'mq_set{set_num}'].loc[mq_index, "name"]
    mq_type = mq_sets[f'mq_set{set_num}'].loc[mq_index, "type"]

    
    # append the results and data to the "results" list
    results.append({
        'candid': slim_candid,
#         'objectId': slim_objectId,
        'mq_name': mq_name,
        "mq_type": mq_type,
        'smallest_dist': smallest_dist
    })

# create the smallest_distances dataset from the "results" list
smallest_distances = pd.DataFrame(results)

print(smallest_distances)
# Out:
# Processing coordinates: 100%|██████████████████████████████████████████████████████| 4155/4155 [24:24<00:00,  2.84it/s]
#                    candid                   mq_name mq_type  \
# 0     2350254161615010002  SDSS J114518.56+183521.7       X
# 1     2350254161615010003  SDSS J114532.90+183027.2       X
# 2     2350254161615010004  SDSS J114448.24+182810.1       Q
# 3     2350254161615015005  SDSS J114844.24+180640.5       Q
# 4     2350254161715010008  SDSS J114404.76+180518.0       Q
# ...                   ...                       ...     ...
# 4150  2350383181115015021  SDSS J214651.27+224355.3       Q
# 4151  2350383181515010005  SDSS J214611.98+230735.0       Q
# 4152  2350383181515010017  Gaia 1839116815899951104       R
# 4153  2350383181515010018  Gaia 1839116815899951104       R
# 4154  2350383181515010019  SDSS J215148.47+222638.4       Q
#
#            smallest_dist
# 0      0d00m00.05505735s
# 1      0d36m00.37244683s
# 2      0d41m24.70582745s
# 3      0d40m48.12622803s
# 4      0d00m00.10260057s
# ...                  ...
# 4150  10d51m55.62289788s
# 4151  11d48m57.37424088s
# 4152   0d24m42.47926469s
# 4153   0d00m00.16677494s
# 4154  13d28m06.98704613s
#
# [4155 rows x 4 columns]

# %%
# define the angle and threshold; the angle is a string and must be converted into an angle
angle_str = "00d00m02s"
threshold = Angle(angle_str)

# Extract the numerical value in degrees from the 'smallest_dist' column
degrees_values = smallest_distances['smallest_dist'].apply(lambda x: x.to_value('deg'))

# Compare the numerical values with the threshold value
filtered_distances = smallest_distances[degrees_values < threshold.to_value('deg')]

print(filtered_distances)
#set 13 returned 132 results 
#set 12 returned 160 results
# Out:
#                    candid                   mq_name mq_type      smallest_dist
# 0     2350254161615010002  SDSS J114518.56+183521.7       X  0d00m00.05505735s
# 4     2350254161715010008  SDSS J114404.76+180518.0       Q  0d00m00.10260057s
# 7     2350254162415015004  SDSS J113244.99+182459.8       Q  0d00m00.70321117s
# 8     2350254162515010002  SDSS J112820.33+181024.0       Q  0d00m00.47725709s
# 9     2350254162515015005  SDSS J112741.88+181416.1       Q  0d00m00.39079179s
# ...                   ...                       ...     ...                ...
# 1427  2350360041415015015  SDSS J161947.55+222706.3       Q  0d00m00.11816752s
# 2282  2350377451115010059  Gaia 4529206909584684928       R  0d00m00.16967382s
# 3256  2350382693915010033  Gaia 1816368298276103552       X  0d00m00.05481804s
# 3826  2350382695515015009  LAMOSTJ201825.48+213114.       A  0d00m00.13426331s
# 4153  2350383181515010018  Gaia 1839116815899951104       R  0d00m00.16677494s
#
# [601 rows x 4 columns]

# %%
results_dir = data_dir.parent.joinpath("Results")
results_dir.mkdir(exist_ok=True)
results = results_dir.joinpath(f'smallestdist{set_num}')
filtered_distances.to_csv(results, index=False)

# mq_output_dir = data_dir.parent.joinpath(f'Sorted_Milliquas_{nb_bin}')
# mq_output_dir.mkdir(exist_ok=True)

# mq_savepath=mq_output_dir.joinpath('milliquas_data.csv')
# mq_data.to_csv(mq_savepath)

# for i in dec_index_mq:
#     mask = mq_data['mq_cut'] == i
#     mq_cut_df = mq_data[mask]
#     mq_altpath = mq_output_dir.joinpath(f'milliquas_range_{i}.csv')
#     mq_cut_df.to_csv(mq_altpath, index = True)
